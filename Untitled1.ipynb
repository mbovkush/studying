# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#        imdb_id    budget    revenue               original_title  \
# 284  tt1078940  70000000  171844840              Couples Retreat
# 314  tt1045772  13000000   10652035    I Love You Phillip Morris
# 258  tt1001508  40000000  177259441  He's Just Not That Into You
# 509  tt0252866  30000000  287553595               American Pie 2
# 501  tt0126029  60000000  484409218                        Shrek
#
#                                                   cast  \
# 284  Vince Vaughn|Malin Ã…kerman|Jason Bateman|Kris...
# 314  Jim Carrey|Ewan McGregor|Leslie Mann|Rodrigo S...
# 258  Jennifer Aniston|Jennifer Connelly|Drew Barrym...
# 509  Jason Biggs|Thomas Ian Nicholas|Chris Klein|Se...
# 501  Mike Myers|Eddie Murphy|Cameron Diaz|John Lith...
#
#                         director  \
# 284            Peter Billingsley
# 314     Glenn Ficarra|John Requa
# 258                   Ken Kwapis
# 509                  J.B. Rogers
# 501  Andrew Adamson|Vicky Jenson
#
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %%
data.original_title[data.budget == data.budget.max()]
# Out:
# 723    Pirates of the Caribbean: On Stranger Tides
# Name: original_title, dtype: object

# %%
data.loc[data.budget == data.budget.max()]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year
# 723           6.3          2011

# %%
data['genres'] = data['genres'].apply(lambda x:x.split('|'))  а потом Counter(data.explode('genres')['genres']).most_common(1)

pd.Series(data['genres'].str.cat(sep='|').split('|')).value_counts()[:5]
string = data.genres.str.cat(sep='|')
divide = pd.Series(string.split('|'))
И просто считаем количество жанров
divide.value_counts().head()
Можно это сделать с помощью Counter:
Counter(data.genres.str.cat(sep='|').split('|')).most_common(1)

data = pd.read_csv('movie_bd_v5.csv')
data['genres'] = data['genres'].apply(lambda x:x.split('|'))

Добрый вечер.
Разделяете жанры.
Применяете explode
Оставляете те жанры, у которых профит >0
Считаете значения
Вместо 2 и 4 можно пройтись по столбцу в цикле и посчитать жанры с помощью collection.Counter, но так дольше )

# %%
data = pd.read_csv('movie_bd_v5.csv')
data['genres'] = data['genres'].apply(lambda x:x.split('|'))

# %%
display(data['genres'])
# Out:
# 0       [Action, Adventure, Science Fiction, Thriller]
# 1       [Action, Adventure, Science Fiction, Thriller]
# 2               [Adventure, Science Fiction, Thriller]
# 3        [Action, Adventure, Science Fiction, Fantasy]
# 4                            [Action, Crime, Thriller]
#                              ...
# 1884              [Adventure, Action, Science Fiction]
# 1885                         [Horror, Family, Foreign]
# 1886    [Adventure, Animation, Action, Comedy, Family]
# 1887                                   [Comedy, Drama]
# 1888                                        [Thriller]
# Name: genres, Length: 1889, dtype: object

# %%
data = pd.read_csv('movie_bd_v5.csv')
display(data['genres'])
type(data['genres'][0])
# Out:
# 0       Action|Adventure|Science Fiction|Thriller
# 1       Action|Adventure|Science Fiction|Thriller
# 2              Adventure|Science Fiction|Thriller
# 3        Action|Adventure|Science Fiction|Fantasy
# 4                           Action|Crime|Thriller
#                           ...
# 1884             Adventure|Action|Science Fiction
# 1885                        Horror|Family|Foreign
# 1886     Adventure|Animation|Action|Comedy|Family
# 1887                                 Comedy|Drama
# 1888                                     Thriller
# Name: genres, Length: 1889, dtype: object
# str

# %%
type(data['genres'][0])
# Out:
# str

# %%
type(data['director'][0])
# Out:
# str

# %%
data['director'] = data['director'].apply(lambda x:x.split('|'))
data_13 = data.explode('director')
display(data_13)
data_13.groupby(['director'])['revenue'].sum().sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ae7c147340f9> in <module>
# ----> 1 data['director'] = data['director'].apply(lambda x:x.split('|'))
#       2 data_13 = data.explode('director')
#       3 display(data_13)
#       4 data_13.groupby(['director'])['revenue'].sum().sort_values(ascending = False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-36-ae7c147340f9> in <lambda>(x)
# ----> 1 data['director'] = data['director'].apply(lambda x:x.split('|'))
# ...

# %%
data_13.groupby(['director'])['revenue'].sum().sort_values(ascending = False).head(1)
# Out:
# director
# Peter Jackson    6490593685
# Name: revenue, dtype: int64

# %%
data['director'] = data['director'].apply(lambda x:x.split('|'))
data['genres'] = data['genres'].apply(lambda x:x.split('|'))
data_14 = data.explode('director')
data_14 = data.explode('genres')

# %%
data['director'] = data['director'].apply(lambda x:x.split('|'))
data_14 = data.explode('director')
data_14['genres'] = data_14['genres'].apply(lambda x:x.split('|'))
data_14 = data_14.explode('genres')
display(data_14)
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# ...         ...        ...         ...                                   ...
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
data['director'] = data['director'].apply(lambda x:x.split('|'))
data_14 = data.explode('director')
data_14[data_14.genres.str.contains("Action")].director.value_counts().sort_values(ascending=False)
# Out:
# Robert Rodriguez      9
# Paul W.S. Anderson    7
# Michael Bay           7
# Antoine Fuqua         6
# Ridley Scott          6
#                      ..
# Patrick Tatopoulos    1
# John A. Davis         1
# Karyn Kusama          1
# Jon Amiel             1
# Jay Chandrasekhar     1
# Name: director, Length: 364, dtype: int64

# %% [markdown]
# Вам нужно отобрать фильмы 2012 года.
# Затем из них отобрать те фильмы, кассовые сборы которых выше среднего значения.
# Потом для каждого актера из этих фильмов посчитать, в скольки фильмах он принял участие. Актер снявшийся в большем количестве фильмов и есть искомый актер

# %%
data_2012 = data[(data.release_year == 2012) & (data.revenue == data.revenue.sum())]
display(data_2012)
# Out:
# Empty DataFrame
# Columns: [imdb_id, budget, revenue, original_title, cast, director, tagline, overview, runtime, genres, production_companies, release_date, vote_average, release_year]
# Index: []

# %%
data['cast'] = data['cast'].apply(lambda x:x.split('|'))
data_15 = data.explode('cast')
display(data_15)
# Out:
#         imdb_id     budget     revenue  original_title                 cast  \
# 0     tt0369610  150000000  1513528810  Jurassic World          Chris Pratt
# 0     tt0369610  150000000  1513528810  Jurassic World  Bryce Dallas Howard
# 0     tt0369610  150000000  1513528810  Jurassic World          Irrfan Khan
# 0     tt0369610  150000000  1513528810  Jurassic World    Vincent D'Onofrio
# 0     tt0369610  150000000  1513528810  Jurassic World        Nick Robinson
# ...         ...        ...         ...             ...                  ...
# 1888  tt0163676   15000000     5217498    The In Crowd           Susan Ward
# 1888  tt0163676   15000000     5217498    The In Crowd         Lori Heuring
# 1888  tt0163676   15000000     5217498    The In Crowd       Matthew Settle
# 1888  tt0163676   15000000     5217498    The In Crowd        Nathan Bexton
# 1888  tt0163676   15000000     5217498    The In Crowd          Tess Harper
#
#              director                       tagline  \
# ...

# %%
data_15.groupby(['cast'])['revenue'].sum()
# Out:
# cast
# 50 Cent                    338878201
# A.J. Cook                   90426405
# Aaliyah                    136515870
# Aamir Khan                  70000000
# Aaran Thomas                82169884
#                              ...
# ZoÃ« Bell                   25037897
# ZoÃ« Borde                 108782847
# ZoÃ« Kravitz               243843127
# Zuleikha Robinson          108103450
# Ã“lafur Darri Ã“lafsson    140396650
# Name: revenue, Length: 3406, dtype: int64

# %%
data_15 = data[data.release_year == 2012]
display(data_15)
# Out:
#         imdb_id     budget     revenue              original_title  \
# 970   tt0848228  220000000  1519557910                The Avengers
# 971   tt1496025   70000000   132400000       Underworld: Awakening
# 972   tt1345836  250000000  1081041287       The Dark Knight Rises
# 973   tt1853728  100000000   425368238            Django Unchained
# 974   tt1074638  200000000  1108561013                     Skyfall
# ...         ...        ...         ...                         ...
# 1076  tt1433822   17000000     9627492              The Apparition
# 1077  tt1480656   20500000     6063556                  Cosmopolis
# 1078  tt1855325   65000000   240159255  Resident Evil: Retribution
# 1079  tt1876451   14000000    24637469                     Sparkle
# 1080  tt2215719   12000000    32726956      Katy Perry: Part of Me
#
#                                                    cast  \
# 970   Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...
# ...

# %%
data['cast'] = data['cast'].apply(lambda x:x.split('|'))
data_15 = data.explode('cast')
data_15 = data_15[data_15.release_year == 2012]
display(data_15)
# Out:
#         imdb_id     budget     revenue          original_title  \
# 970   tt0848228  220000000  1519557910            The Avengers
# 970   tt0848228  220000000  1519557910            The Avengers
# 970   tt0848228  220000000  1519557910            The Avengers
# 970   tt0848228  220000000  1519557910            The Avengers
# 970   tt0848228  220000000  1519557910            The Avengers
# ...         ...        ...         ...                     ...
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
#
#                     cast                   director  \
# 970    Robert Downey Jr.                Joss Whedon
# 970          Chris Evans                Joss Whedon
# ...

# %%
data_15.groupby(['cast'])['revenue'].sum().sort_values(ascending=False)
# Out:
# cast
# Chris Hemsworth      2027450773
# Denis Leary          1629460639
# Anne Hathaway        1522851057
# Chris Evans          1519557910
# Robert Downey Jr.    1519557910
#                         ...
# Jason Bateman           3428048
# Danny Huston            2106557
# Sami Gayle              2106557
# Josh Lucas              2106557
# Nicolas Cage            2106557
# Name: revenue, Length: 466, dtype: int64

# %%
data['cast'] = data['cast'].apply(lambda x:x.split('|'))
data_16 = data.explode('cast')
display(data_16)
#data.revenue > data.revenue.mean()
# Out:
#         imdb_id     budget     revenue  original_title                 cast  \
# 0     tt0369610  150000000  1513528810  Jurassic World          Chris Pratt
# 0     tt0369610  150000000  1513528810  Jurassic World  Bryce Dallas Howard
# 0     tt0369610  150000000  1513528810  Jurassic World          Irrfan Khan
# 0     tt0369610  150000000  1513528810  Jurassic World    Vincent D'Onofrio
# 0     tt0369610  150000000  1513528810  Jurassic World        Nick Robinson
# ...         ...        ...         ...             ...                  ...
# 1888  tt0163676   15000000     5217498    The In Crowd           Susan Ward
# 1888  tt0163676   15000000     5217498    The In Crowd         Lori Heuring
# 1888  tt0163676   15000000     5217498    The In Crowd       Matthew Settle
# 1888  tt0163676   15000000     5217498    The In Crowd        Nathan Bexton
# 1888  tt0163676   15000000     5217498    The In Crowd          Tess Harper
#
#              director                       tagline  \
# ...

# %%
data_16 = data_16[data_16.budget > data_16.budget.mean()]
display(data_16)
# Out:
#         imdb_id     budget     revenue     original_title  \
# 0     tt0369610  150000000  1513528810     Jurassic World
# 0     tt0369610  150000000  1513528810     Jurassic World
# 0     tt0369610  150000000  1513528810     Jurassic World
# 0     tt0369610  150000000  1513528810     Jurassic World
# 0     tt0369610  150000000  1513528810     Jurassic World
# ...         ...        ...         ...                ...
# 1857  tt0177971  120000000   325756637  The Perfect Storm
# 1857  tt0177971  120000000   325756637  The Perfect Storm
# 1857  tt0177971  120000000   325756637  The Perfect Storm
# 1857  tt0177971  120000000   325756637  The Perfect Storm
# 1857  tt0177971  120000000   325756637  The Perfect Storm
#
#                      cast           director               tagline  \
# 0             Chris Pratt    Colin Trevorrow     The park is open.
# 0     Bryce Dallas Howard    Colin Trevorrow     The park is open.
# ...

# %%
data_16[data_16.budget > data_16.budget.mean()]['cast'].value_counts()
# Out:
# Matt Damon               18
# Adam Sandler             17
# Angelina Jolie           16
# Samuel L. Jackson        15
# Eddie Murphy             15
#                          ..
# Christopher Eccleston     1
# Lymari Nadal              1
# Karin Konoval             1
# John Hawkes               1
# Jay Chou                  1
# Name: cast, Length: 1505, dtype: int64

# %%
data_16.loc[data_16['budget'] > data_16['budget'].mean()]['cast'].value_counts(ascending=False)
# Out:
# Matt Damon               18
# Adam Sandler             17
# Angelina Jolie           16
# Samuel L. Jackson        15
# Eddie Murphy             15
#                          ..
# Christopher Eccleston     1
# Lymari Nadal              1
# Karin Konoval             1
# John Hawkes               1
# Jay Chou                  1
# Name: cast, Length: 1505, dtype: int64

# %%
data = pd.read_csv('movie_bd_v5.csv')
data_16 = data[data.budget > data.budget.mean()]
Counter(data_16.cast.str.cat(sep='|').split('|')).most_common(1)
# Out:
# [('Matt Damon', 18)]

# %%
data = pd.read_csv('movie_bd_v5.csv')
data['cast'] = data['cast'].apply(lambda x:x.split('|'))
data_16 = data.explode('cast')
data_16[data_16.budget > data_16.budget.mean()]['cast'].value_counts()
# Out:
# Matt Damon               18
# Adam Sandler             17
# Angelina Jolie           16
# Samuel L. Jackson        15
# Eddie Murphy             15
#                          ..
# Christopher Eccleston     1
# Lymari Nadal              1
# Karin Konoval             1
# John Hawkes               1
# Jay Chou                  1
# Name: cast, Length: 1505, dtype: int64

# %%
data = pd.read_csv('movie_bd_v5.csv')
data['cast'] = data['cast'].apply(lambda x:x.split('|'))
data_17 = data.explode('cast')
data_17 = data_17[data_17.cast == 'Nicolas Cage']
data_17['genres'] = data_17['genres'].apply(lambda x:x.split('|'))
data_17_genres = data_17.explode('genres')
data_17_1 = data_17_genres.genres.value_counts()
display(data_17_1)
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Animation           3
# Family              3
# Mystery             3
# History             2
# Romance             1
# Horror              1
# War                 1
# Name: genres, dtype: int64

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.loc[data['vote_average']>data.quantile(0.99, numeric_only=True)['vote_average']]['original_title']
# Out:
# 9                                          Inside Out
# 34                                               Room
# 118                                      Interstellar
# 119                           Guardians of the Galaxy
# 125                                The Imitation Game
# 128                                         Gone Girl
# 138                          The Grand Budapest Hotel
# 370                                         Inception
# 599                                   The Dark Knight
# 872                                       The Pianist
# 1081    The Lord of the Rings: The Return of the King
# 1183                          The Wolf of Wall Street
# 1191                                 12 Years a Slave
# 1800                                          Memento
# Name: original_title, dtype: object

# %%
type(data['cast'][0])
# Out:
# str

# %%
len('Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan')
# Out:
# 83
