# %%
import json
with open('DSjson.json', 'rb') as infile:
    data = json.load(infile)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['events_data'])

# %%
data['events_data']
# Out:
# [{'id': 47946124,
#   'client_id': 62526,
#   'user_id': 110777,
#   'category': 'page',
#   'action': 'enter',
#   'options': {'name': 'landing'}},
#  {'id': 47947076,
#   'client_id': 61944,
#   'user_id': 108565,
#   'category': 'page',
#   'action': 'enter',
#   'options': {'name': 'landing'}},
#  {'id': 47962056,
#   'client_id': 27115,
#   'user_id': 49440,
#   'category': 'page',
#   'action': 'enter',
#   'options': {'name': 'page'}},
#  {'id': 47962120,
#   'client_id': 27115,
#   'user_id': 49440,
#   'category': 'datepicker',
#   'action': 'apply',
#   'options': {'endDate': '2019-03-31 23:59:59',
#    'startDate': '2019-03-25 00:00:00'}},
#  {'id': 47962218,
#   'client_id': 27115,
#   'user_id': 49440,
#   'category': 'table',
#   'action': 'sort',
#   'options': {'dir': 'ASC', 'name': 'deal_date'}},
#  {'id': 47962238,
#   'client_id': 27115,
#   'user_id': 49440,
#   'category': 'table',
#   'action': 'sort',
#   'options': {'dir': 'DESC', 'name': 'deal_date'}},
# ...

# %%
data_list = data['events_data']

# %%
print(len(data_list))
# Out:
# 107

# %%
categories = []
for item in data_list:
    category = item['category']
    categories.append(category)
print(categories)
# Out:
# ['page', 'page', 'page', 'datepicker', 'table', 'table', 'table', 'table', 'datepicker', 'datepicker', 'datepicker', 'datepicker', 'datepicker', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'report', 'report', 'report', 'report', 'page', 'report', 'page', 'page', 'page', 'table', 'table', 'table', 'table', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'report', 'page', 'page', 'page', 'page', 'page', 'report', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'datepicker', 'datepicker', 'datepicker', 'datepicker', 'datepicker', 'datepicker', 'datepicker', 'page', 'page', 'page', 'page', 'page', 'page', 'report', 'table', 'table', 'datepicker', 'datepicker', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page', 'page']

# %%
import collections
c = collections.Counter()
for category in categories:
    c[category] += 1
print(c)
# Out:
# Counter({'page': 74, 'datepicker': 15, 'table': 10, 'report': 8})

# %%
table_clients = []
for item in data_list:
    client_id = item['client_id']
    category = item['category']
    if category == 'table':
        table_clients.append(client_id)
print(table_clients)
# Out:
# [27115, 27115, 27115, 27115, 60459, 60459, 60459, 60459, 58113, 58113]

# %%
c = collections.Counter()
for table_client in table_clients:
    c[table_client] += 1
print(c)
# Out:
# Counter({27115: 4, 60459: 4, 58113: 2})

# %%
print(len(c.keys()))
# Out:
# 3

# %%
print(c[27115])
# Out:
# 4

# %%
actions = []
for item in data_list:
    action = item['action']
    actions.append(action)
print(len(actions))
# Out:
# 107

# %%
c = collections.Counter()
for client_id in data_list:
    c[action] += 1
print(c)
# Out:
# Counter({'enter': 74, 'apply': 15, 'sort': 10, 'change_mode': 6, 'link_click': 2})

# %%
clients = []
for table_client in data_list:
    if table_client['client_id'] not in clients:
        clients.append(table_client['client_id'])
len(clients)
# Out:
# 51

# %%
act = 0
for client in data_list:
    if client['client_id'] == 60459:
        act += 1
print(act)
# Out:
# 12

# %%
act_1 = 0
for client in data_list:
    if client['category'] == 'page' and client['client_id'] == 62602:
        act_1 += 1
print(act_1)
# Out:
# 9

# %%
clients_report = []
for client in data_list:
    if client['category'] == 'report' and client['client_id'] not in clients_report:
        clients_report.append(client['client_id'])
print(len(clients_report))
clients_report.sort()
print(clients_report)
# Out:
# 3
# [58113, 60459, 62602]
