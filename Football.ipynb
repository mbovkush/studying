# %% [markdown]
# import pandas as pd
# data = pd.Series(list(range(10, 1001)))

# %%
print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8bae8cc277af> in <module>
# ----> 1 print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
#
# NameError: name 'data' is not defined

# %%
import pandas as pd 
data = pd.Series(list(range(10, 1001)))
display(data)
# Out:
# 0        10
# 1        11
# 2        12
# 3        13
# 4        14
#        ...
# 986     996
# 987     997
# 988     998
# 989     999
# 990    1000
# Length: 991, dtype: int64

# %%
print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
# Out:
# -70

# %%
data
# Out:
# 0        10
# 1        11
# 2        12
# 3        13
# 4        14
#        ...
# 986     996
# 987     997
# 988     998
# 989     999
# 990    1000
# Length: 991, dtype: int64

# %%
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
display(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
import pandas as pd
football = pd.read_csv('data_sf.csv')
display(football.head())
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
display(football.tail(7))
# Out:
#        Unnamed: 0                Name  Age          Nationality  \
# 12890       13119            J. Young   18             Scotland
# 12891       13120            D. Walsh   18  Republic of Ireland
# 12892       13121        J. Lundstram   19              England
# 12893       13122  N. Christoffersson   19               Sweden
# 12894       13123           B. Worman   16              England
# 12895       13124      D. Walker-Rice   17              England
# 12896       13125           G. Nugent   16              England
#
#                    Club    Value  Wage Position  Crossing  Finishing  ...  \
# 12890      Swindon Town   450000  1000       ST        28         47  ...
# 12891      Waterford FC    60000  1000       RB        22         23  ...
# 12892   Crewe Alexandra  1100000  1000       CM        34         38  ...
# 12893    Trelleborgs FF    60000  1000       ST        23         52  ...
# 12894  Cambridge United    60000  1000       ST        25         40  ...
# ...

# %%
display(football.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
football.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
football.describe(include = ['object'])
# Out:
#                 Name Nationality              Club Position
# count          12897       12897             12897    12897
# unique         12326         156               650       27
# top     J. Rodríguez     England  V-Varen Nagasaki       GK
# freq               9        1368                30     1641

# %%
import pandas as pd
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
display(df)
df.mean()
# Out:
#    foo   bar  baz foobar
# 0    0   1.2    2     hi
# 1    1   2.2    3     hi
# 2    2   3.2    4     hi
# 3    3   4.2    5     hi
# 4    4   5.2    6     hi
# 5    5   6.2    7     hi
# 6    6   7.2    8     hi
# 7    7   8.2    9     hi
# 8    8   9.2   10     hi
# 9    9  10.2   11     hi
# foo    4.5
# bar    5.7
# baz    6.5
# dtype: float64

# %%
football = pd.read_csv('data_sf.csv')
football.Age.mean()
# Out:
# 24.795378770256647

# %%
football.Composure.count()
# Out:
# 12897

# %%
football[['Age', 'Value']]
# Out:
#        Age      Value
# 0       31  110500000
# 1       33   77000000
# 2       26  118500000
# 3       27   72000000
# 4       27  102000000
# ...    ...        ...
# 12892   19    1100000
# 12893   19      60000
# 12894   16      60000
# 12895   17      60000
# 12896   16      60000
#
# [12897 rows x 2 columns]

# %%
football[football.Age > 20]
type(football['Age'])
# Out:
# pandas.core.series.Series

# %%
display(football.loc[0])
# Out:
# Unnamed: 0                    0
# Name                   L. Messi
# Age                          31
# Nationality           Argentina
# Club               FC Barcelona
# Value                 110500000
# Wage                     565000
# Position                     RF
# Crossing                     84
# Finishing                    95
# HeadingAccuracy              70
# ShortPassing                 90
# Volleys                      86
# Dribbling                    97
# Curve                        93
# FKAccuracy                   94
# LongPassing                  87
# BallControl                  96
# Acceleration                 91
# SprintSpeed                  86
# Agility                      91
# Reactions                    95
# Balance                      95
# ShotPower                    85
# Jumping                      68
# Stamina                      72
# Strength                     59
# LongShots                    94
# Aggression                   48
# ...

# %%
football.ShortPassing.std()
# Out:
# 14.740435689517149

# %%
football.Wage.sum()
# Out:
# 96954000

# %%
football.Value.min()
# Out:
# 0

# %%
import pandas as pd
football = pd.read_csv('data_sf.csv')
football[football.Wage < football.Wage.mean()].SprintSpeed.mean()
# Out:
# 62.41425430560645

# %%
football.Position.football[football.Wage.max()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e4a148bf7fd0> in <module>
# ----> 1 football.Position.football[football.Wage.max()]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'football'

# %%
football[football.Wage == football.Wage.max()].Position
# Out:
# 0    RF
# Name: Position, dtype: object

# %%
football[football.Nationality == 'Brazil'].Penalties.sum()
# Out:
# 22789

# %%
football[football.HeadingAccuracy > 50].Age.mean()
# Out:
# 25.58771113179944

# %%
football[(football.Composure > (0.9 * football.Composure.max()))&
        (football.Reactions > (0.9 * football.Reactions.max()))].Age.min()
# Out:
# 24

# %%
x = football[football.Age == football.Age.max()].Reactions.mean() - \
    football[football.Age == football.Age.min()].Reactions.mean()
print(x)
# Out:
# 22.642857142857146

# %%
football[football.Value > football.Value.mean()].Nationality.describe().top
# Out:
# 'Spain'

# %%
y = football[(football.Position == 'GK') & (football.GKReflexes == football.GKReflexes.max())].Wage.mean()
z = football[(football.Position == 'GK') & (football.GKHandling == football.GKHandling.max())].Wage.mean()
print(y / z)
# Out:
# 2.765957446808511

# %%
a = football[football.Aggression == football.Aggression.max()].ShotPower.mean()
b = football[football.Aggression == football.Aggression.min()].ShotPower.mean()
print(a/b)
# Out:
# 2.076923076923077

# %%
import pandas as pd
df = pd.read_csv('data_sf.csv')

# %%
clubs = df['Club'].value_counts()
display(clubs)
# Out:
# V-Varen Nagasaki     30
# Shonan Bellmare      30
# Padova               29
# De Graafschap        29
# Vissel Kobe          29
#                      ..
# FC Metz               8
# GD Chaves             7
# Dinamo Zagreb         7
# Vitória Guimarães     7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %%
len(clubs)
# Out:
# 650

# %%
clubs.index
# Out:
# Index(['Real Madrid', 'FC Barcelona', 'Juventus', 'Manchester City',
#        'Atlético Madrid', 'Chelsea', 'Paris Saint-Germain',
#        'FC Bayern München', 'Manchester United', 'Tottenham Hotspur'],
#       dtype='object')

# %%
len(clubs.index)
# Out:
# 10

# %%
import pandas as pd
df = pd.read_csv('data_sf.csv')
pos = df['Position'].value_counts(normalize=True)
display(pos)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# RF     0.000465
# LAM    0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
small_df = df[df.columns[0:7]].head(25)
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
s.index
# Out:
# IntervalIndex([(211750.0, 329500.0], (93528.999, 211750.0], (329500.0, 447250.0], (447250.0, 565000.0]],
#               closed='right',
#               dtype='interval[float64]')

# %%
s.index[3]
# Out:
# Interval(447250.0, 565000.0, closed='right')

# %%
s.index[3].left
# Out:
# 447250.0

# %%
s.index[3].right
# Out:
# 565000.0

# %%
small_df['Wage'] > s.index[3].left
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# Name: Wage, dtype: bool

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#    Unnamed: 0       Name  Age Nationality          Club      Value    Wage
# 0           0   L. Messi   31   Argentina  FC Barcelona  110500000  565000
# 7           7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000

# %%
accuracy = df['FKAccuracy'].value_counts(bins=5)
display(accuracy)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
result = len(df['Position'].unique())
display(result)
# Out:
# 27

# %%
result = df['Position'].nunique()
result
# Out:
# 27

# %%
result = df['Position'].unique()
result
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
result = df['Position'].count()
result
# Out:
# 12897

# %%
result = len(df['Position'].value_counts())
result
# Out:
# 27

# %%
x = 2
y = 5
x
y
# Out:
# 5

# %%
display(x)
# Out:
# 2

# %%
import pandas as pd
df = pd.read_csv('data_sf.csv')
wage_sp = df[df.Nationality == 'Spain'].Wage.value_counts(bins=4, normalize=True)
display(wage_sp)
# Out:
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %%
nat_unique = df[df.Club == 'Manchester United'].Nationality.nunique()
display(nat_unique)
# Out:
# 13

# %%
names = df[(df.Nationality == 'Brazil')&(df.Club == 'Juventus')].Name.unique()
display(names)
print(names.sort())
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)
# None

# %%
clubs_age = df[df.Age > 35].Club.value_counts()
display(clubs_age)
# Out:
# Hokkaido Consadole Sapporo    4
# Club Atlético Huracán         4
# Hammarby IF                   3
# Nagoya Grampus                3
# Club Atlético Talleres        3
#                              ..
# Guadalajara                   1
# CD O'Higgins                  1
# Cádiz CF                      1
# Vélez Sarsfield               1
# Gamba Osaka                   1
# Name: Club, Length: 212, dtype: int64

# %%
age_arg = df[df.Nationality == 'Argentina'].Age.value_counts(bins=4)
display(age_arg)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
nation = df.Nationality.value_counts()
display(nation)
age = df[df.Age == 21].Nationality.value_counts()
display(age)
# Out:
# England      1368
# Germany       919
# Spain         671
# France        614
# Argentina     574
#              ...
# Belize          1
# St Lucia        1
# Libya           1
# Jordan          1
# Ethiopia        1
# Name: Nationality, Length: 156, dtype: int64
# England       109
# Germany        89
# Spain          79
# France         50
# China PR       45
#              ...
# Iceland         1
# Zambia          1
# Madagascar      1
# Hungary         1
# Angola          1
# Name: Nationality, Length: 83, dtype: int64

# %%
percent = (age['Spain'] / nation['Spain'])*100
print(percent)
# Out:
# 11.773472429210134

# %%
(df[df.Nationality =='Spain'].Age.value_counts(normalize=True)*100).loc[21]
# Out:
# 11.773472429210134

# %%
grouped_df = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.loc[grouped_df > 5000000])
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# Name: Wage, dtype: int64

# %%
grouped_df = df.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False)
print(grouped_df.head(5))
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06

# %%
wage = df.groupby(['Club'])[['Wage']].agg(['mean', 'median'])
display(wage)
print(wage.loc[wage > 5000000])
# Out:
#                               Wage
#                               mean median
# Club
#  SSV Jahn Regensburg   3750.000000   3500
# 1. FC Heidenheim 1846  3800.000000   3000
# 1. FC Kaiserslautern   1434.782609   1000
# 1. FC Köln             9200.000000   4000
# 1. FC Magdeburg        4000.000000   4000
# ...                            ...    ...
# Zagłębie Sosnowiec     1080.000000   1000
# Çaykur Rizespor        5363.636364   4500
# Örebro SK              1384.615385   1000
# Östersunds FK          1950.000000   1000
# Śląsk Wrocław          2083.333333   2000
#
# [650 rows x 2 columns]

# %%
group = (df.groupby(['Club'])['Wage'].agg(['mean', 'median']))
new_df = (group[group['mean'] == group['median']])
sorted = new_df.sort_values(['mean'], ascending=False)
print(sorted)
display(sorted)
new_df.count()
# Out:
#                            mean  median
# Club
# Cruzeiro                13000.0   13000
# Göztepe SK               7000.0    7000
# Brøndby IF               6000.0    6000
# Sunderland               4000.0    4000
# CD Feirense              4000.0    4000
# 1. FC Magdeburg          4000.0    4000
# Northampton Town         2500.0    2500
# Stade Brestois 29        2000.0    2000
# Jeonnam Dragons          2000.0    2000
# Pohang Steelers          2000.0    2000
# AJ Auxerre               2000.0    2000
# Grimsby Town             2000.0    2000
# Heracles Almelo          2000.0    2000
# Philadelphia Union       2000.0    2000
# Kashiwa Reysol           2000.0    2000
# CD Tondela               2000.0    2000
# Benevento                2000.0    2000
# FC Metz                  1500.0    1500
# PAOK                     1000.0    1000
# Orlando Pirates          1000.0    1000
# Panathinaikos FC         1000.0    1000
# Patriotas Boyacá FC      1000.0    1000
# ...

# %%
chelsea = df.groupby(['Club'])[['Wage']].sum()
display(chelsea.loc['Chelsea'])
# Out:
# Wage    2035000
# Name: Chelsea, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('data_sf.csv')
df_1 = df[(df.Nationality == 'Argentina')&(df.Age == 30)].Wage.min()
display(df_1)
# Out:
# 1000

# %%
df_2 = df[(df.Nationality == 'Argentina')&(df.Club == 'FC Barcelona')][['Strength','Balance']].max()
display(df_2)
# Out:
# Strength    59
# Balance     95
# dtype: int64

# %%
chelsea = df[df.Club == 'Chelsea'][['Wage']].sum()
display(chelsea)
# Out:
# Wage    2035000
# dtype: int64

# %%
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')
display(df2)
# Out:
# Position                   CAM       CB      CDM      CF      CM       GK  \
# Club
#  SSV Jahn Regensburg       NaN   5000.0   5000.0     NaN  4000.0   5000.0
# 1. FC Heidenheim 1846   5000.0   7000.0      NaN     NaN  1000.0   4000.0
# 1. FC Kaiserslautern       NaN   1000.0   1000.0     NaN     NaN   1000.0
# 1. FC Köln                 NaN   1000.0  10000.0     NaN  3000.0  25000.0
# 1. FC Magdeburg            NaN   7000.0      NaN  4000.0     NaN   6000.0
# ...                        ...      ...      ...     ...     ...      ...
# Zagłębie Sosnowiec      2000.0   1000.0   1000.0     NaN     NaN   1000.0
# Çaykur Rizespor        11000.0  11000.0  13000.0     NaN     NaN   3000.0
# Örebro SK                  NaN   2000.0      NaN     NaN  1000.0   2000.0
# Östersunds FK           1000.0   1000.0      NaN  3000.0  8000.0   1000.0
# Śląsk Wrocław              NaN   1000.0   3000.0     NaN  1000.0   2000.0
#
# ...

# %%
df2.loc['Manchester City']['GK']
# Out:
# 125000.0

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True)
display(pivot)
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %%
pivot.loc['Belgium']
# Out:
#       Club
# Wage  FC Barcelona         110000.0
#       Juventus                  NaN
#       Manchester United    230000.0
#       Real Madrid          240000.0
#       All                  580000.0
# Name: Belgium, dtype: float64

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True,
fill_value=0)
display(pivot)
# Out:
#                            Wage                                         \
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                565000   205000            206000           0
# Belgium                  110000        0            230000      240000
# Bosnia Herzegovina            0   180000                 0           0
# Brazil                   465000   335000             91000      570000
# Chile                    205000        0            215000           0
# Costa Rica                    0        0                 0      195000
# Croatia                  260000   160000                 0      420000
# Dominican Republic            0        0                 0      140000
# Ecuador                       0        0            120000           0
# England                       0        0            478000           0
# France                   495000   145000            375000      459000
# ...

# %%
pivot = df.pivot_table(values='Name',
index='Club',
columns='Position',
aggfunc='count',
fill_value=0)
display(pivot)
# Out:
# Position               CAM  CB  CDM  CF  CM  GK  LAM  LB  LCB  LCM  ...  RB  \
# Club                                                                ...
#  SSV Jahn Regensburg     0   5    1   0   2   3    0   2    0    0  ...   2
# 1. FC Heidenheim 1846    1   3    0   0   1   2    0   2    1    0  ...   2
# 1. FC Kaiserslautern     0   3    3   0   0   3    0   2    1    0  ...   2
# 1. FC Köln               0   1    1   0   2   3    0   0    0    0  ...   1
# 1. FC Magdeburg          0   4    0   1   0   3    0   1    1    1  ...   0
# ...                    ...  ..  ...  ..  ..  ..  ...  ..  ...  ...  ...  ..
# Zagłębie Sosnowiec       3   2    2   0   0   3    0   3    1    0  ...   1
# Çaykur Rizespor          1   2    5   0   0   3    0   2    1    0  ...   3
# Örebro SK                0   4    0   0   1   3    0   0    1    1  ...   0
# Östersunds FK            1   1    0   1   3   3    0   2    1    1  ...   1
# ...

# %%
round(pivot['GK'].mean(),3)
# Out:
# 2.525

# %%
df_new = pivot['CM'].value_counts()[0]
display(df_new)
# Out:
# 1    211
# 2    149
# 0    136
# 3     89
# 4     39
# 5     21
# 6      5
# Name: CM, dtype: int64

# %%
pivot = df.pivot_table(values='Wage',
index='Nationality',
columns='Club',
aggfunc='sum',
fill_value=0)
display(pivot)
# Out:
# Club          SSV Jahn Regensburg  1. FC Heidenheim 1846  \
# Nationality
# Afghanistan                     0                      0
# Albania                         0                      0
# Algeria                         0                      0
# Andorra                         0                      0
# Angola                          0                      0
# ...                           ...                    ...
# Uzbekistan                      0                      0
# Venezuela                       0                      0
# Wales                           0                      0
# Zambia                          0                      0
# Zimbabwe                        0                      0
#
# Club         1. FC Kaiserslautern  1. FC Köln  1. FC Magdeburg  \
# Nationality
# Afghanistan                     0           0                0
# Albania                         0           0                0
# ...

# %%
pivot.loc['Russia']['AS Monaco']
# Out:
# 61000

# %%
pivot_speed = df.pivot_table(values='SprintSpeed',
index='Club',
columns='Position',
aggfunc='mean',
fill_value=0)
display(pivot_speed)
pivot_speed.max().sort_values(ascending=False).head(10)
# Out:
# Position                CAM         CB        CDM    CF         CM         GK  \
# Club
#  SSV Jahn Regensburg    0.0  46.600000  82.000000   0.0  61.000000  33.000000
# 1. FC Heidenheim 1846  68.0  61.333333   0.000000   0.0  68.000000  41.000000
# 1. FC Kaiserslautern    0.0  59.000000  65.666667   0.0   0.000000  42.666667
# 1. FC Köln              0.0  60.000000  32.000000   0.0  68.500000  33.000000
# 1. FC Magdeburg         0.0  60.000000   0.000000  64.0   0.000000  39.333333
# ...                     ...        ...        ...   ...        ...        ...
# Zagłębie Sosnowiec     73.0  46.500000  66.000000   0.0   0.000000  39.000000
# Çaykur Rizespor        74.0  58.000000  62.800000   0.0   0.000000  47.000000
# Örebro SK               0.0  60.750000   0.000000   0.0  63.000000  33.666667
# Östersunds FK          67.0  76.000000   0.000000  77.0  56.333333  32.666667
# Śląsk Wrocław           0.0  62.000000  66.666667   0.0  72.000000  30.666667
#
# ...

# %%
pivot_speed = df.pivot_table(values='SprintSpeed',
index='Club',
columns='Position',
aggfunc='mean',
fill_value=0)
display(pivot_speed)
pivot_speed['ST'].sort_values(ascending=False).head(3)
# Out:
# Position                CAM         CB        CDM    CF         CM         GK  \
# Club
#  SSV Jahn Regensburg    0.0  46.600000  82.000000   0.0  61.000000  33.000000
# 1. FC Heidenheim 1846  68.0  61.333333   0.000000   0.0  68.000000  41.000000
# 1. FC Kaiserslautern    0.0  59.000000  65.666667   0.0   0.000000  42.666667
# 1. FC Köln              0.0  60.000000  32.000000   0.0  68.500000  33.000000
# 1. FC Magdeburg         0.0  60.000000   0.000000  64.0   0.000000  39.333333
# ...                     ...        ...        ...   ...        ...        ...
# Zagłębie Sosnowiec     73.0  46.500000  66.000000   0.0   0.000000  39.000000
# Çaykur Rizespor        74.0  58.000000  62.800000   0.0   0.000000  47.000000
# Örebro SK               0.0  60.750000   0.000000   0.0  63.000000  33.666667
# Östersunds FK          67.0  76.000000   0.000000  77.0  56.333333  32.666667
# Śląsk Wrocław           0.0  62.000000  66.666667   0.0  72.000000  30.666667
#
# ...
