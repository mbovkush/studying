# %%
word = 'box'
print(word[0])
# Out:
# b

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
new_proverb = ''
temp=''
for i in range(0, len(proverb), 2):
    temp=proverb[i:i+2]
    new_proverb+=temp[1]+temp[0]
print(new_proverb)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-b7acfbc4b4f2> in <module>
#       4 for i in range(0, len(proverb)+1, 2):
#       5     temp=proverb[i:i+2]
# ----> 6     new_proverb+=temp[1]+temp[0]
#       7 print(new_proverb)
#
# IndexError: string index out of range

# %%
basic_word = 'программирование'
inverted_word = ''
for letter in basic_word:
    inverted_word = basic_word[ : : -1] 
print(inverted_word)
if inverted_word == basic_word:
    print('Слово' + '""' + basic_word + '""' 'является палиндромом')
else:
    print('Слово' + '""' + basic_word + '""' + 'это не палиндром')
# Out:
# хах
# Слово""хах""является палиндромом

# %%
basic_word = 'программирование'
inverted_word = ''
for letter in basic_word:
    inverted_word = basic_word[ : : -1] 
if inverted_word == basic_word:
    print('Слово' + ' "' + basic_word + '" ' + 'является палиндромом')
else:
    print('Слово' + ' "' + basic_word + '" ' + 'это не палиндром')
# Out:
# еинавориммаргорп
# Слово "программирование" это не палиндром

# %%
basic_word = 'программирование'
inverted_word = ''
for letter in basic_word:
    inverted_word = basic_word[ : : -1] 
if inverted_word == basic_word:
    print('Слово' + ' "' + basic_word + '" ' + 'является палиндромом')
else:
    print('Слово' + ' "' + basic_word + '" ' + 'это не палиндром')
# Out:
# Слово "программирование" это не палиндром

# %%
email = 'VeryBigBoss@skillfactory.ru'
pos = email.find('@')
domain = email[pos+1:]

# %%
domain
# Out:
# 'skillfactory.ru'

# %%
proverb = 'Хорошо написанная программа - это программа, написанная 2 раза'

while True:
    index = proverb.find('программа')
    if index == -1:
        break
    secret = proverb[:index].split()[-1]
    proverb = proverb[index+9:]

# %%
secret
# Out:
# 'это'

# %%
proverb
# Out:
# ', написанная 2 раза'

# %%
email = 'abc@ccc.ru'
email[email.find('@')+1 : ]
# Out:
# 'ccc.ru'

# %%
number = 56.257
num = str(number)
fraction = num[num.find('.')+1:]
fr_sum = 0
for i in fraction:
    fr_sum += int(i)
print(fr_sum)
# Out:
# 14

# %%
emails_list = ['vasya@mail.ru', 
          'akakiy@yandex.ru', 
          'spyderman@yandex.ru', 
          'XFiles@gmail.com', 
          'hello@mail.ru', 
          'noname@gmail.com', 
          'DonaldTrump@mail.ru', 
          'a768#af@yandex.ru', 
          'Ivan_Ivanovich@yandex.ru', 
          'thebestmail@yandex.ru']
emails_dict = {}
import collections
c = collections.Counter()
domains = []
for email in emails_list:
    domain = email[email.find('@')+1:]
   # domains.append(domain)
print(domains)
for domain in domains:
    c[domain] += 1
print(c)
#for key, value in c.items():
emails_dict.update(c)
print(emails_dict)
# Out:
# ['mail.ru', 'yandex.ru', 'yandex.ru', 'gmail.com', 'mail.ru', 'gmail.com', 'mail.ru', 'yandex.ru', 'yandex.ru', 'yandex.ru']
# Counter({'yandex.ru': 5, 'mail.ru': 3, 'gmail.com': 2})
# {'mail.ru': 3, 'yandex.ru': 5, 'gmail.com': 2}

# %% [markdown]
# Дан список emails_list, содержащий электронные адреса десяти человек. Вам нужно написать программу, которая создаёт словарь emails_dict .Ключами словаря должны быть адреса доменов, а значениями — количество электронных адресов из списка emails_list, зарегистрированных на каждом домене.

# %%
emails_list = ['vasya@mail.ru', 
          'akakiy@yandex.ru', 
          'spyderman@yandex.ru', 
          'XFiles@gmail.com', 
          'hello@mail.ru', 
          'noname@gmail.com', 
          'DonaldTrump@mail.ru', 
          'a768#af@yandex.ru', 
          'Ivan_Ivanovich@yandex.ru', 
          'thebestmail@yandex.ru']
import collections
c = collections.Counter()
for email in emails_list:
    domain = email[email.find('@')+1:]
    c[domain] += 1
emails_dict = dict(c)
print(emails_dict)
# Out:
# {'mail.ru': 3, 'yandex.ru': 5, 'gmail.com': 2}

# %%
stroka = "cat"
stroka = stroka.replace(stroka[0], stroka[0].upper())
print(stroka)
# Out:
# Cat

# %%
string = 'Тяжёлая интернет-зависимость - это когда ты выходишь из интернета, а он из тебя нет.'
signs = ['.',',','-','!','?']
for sign in string:
    if sign in signs:
        string= string.replace(sign, ':)')
print(string)
# Out:
# Тяжёлая интернет:)зависимость :) это когда ты выходишь из интернета:) а он из тебя нет:)

# %%
name = 'Севастиан'
vowels = ['а', 'е', 'ё', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']
for letter in name:
    if letter.lower() in vowels:
        print(letter, '- гласная буква')
    else:
        print(letter, '- согласная буква')
# Out:
# С - согласная буква
# е - гласная буква
# в - согласная буква
# а - гласная буква
# с - согласная буква
# т - согласная буква
# и - гласная буква
# а - гласная буква
# н - согласная буква

# %%
import re
pattern = re.compile('[А-Я][а-я]*\W')
string = '!!! Йо! Учиться, учиться и учиться! Вперёд! Только вперёд!' 
pattern.match(string)
pattern.search(string)
#pattern.findall(string)
# Out:
# <re.Match object; span=(4, 7), match='Йо!'>

# %%
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'

# %%
exp = re.compile('\d+')

# %%
exp.search(text)
# Out:
# <re.Match object; span=(44, 48), match='1980'>

# %%
find = re.compile('[Аа]\w\w[Ии]')
find.findall(text)
# Out:
# ['асши', 'амми', 'ающи', 'ающи']

# %%
print(len(find.findall(text)))
# Out:
# 4

# %%
pair = re.compile('[АЕЁИОУЫЭЮЯаеёиоуыэюя]\s[^АЕЁИОУЫЭЮЯаеёиоуыэюя0-9A-Za-z]')
pair.findall(text)
print(len(pair.findall(text)))
# Out:
# 22

# %%
pair.findall(text)
# Out:
# ['а н',
#  'а в',
#  'о в',
#  'я р',
#  'я р',
#  'и Г',
#  'о н',
#  'а д',
#  'е н',
#  'и д',
#  'о н',
#  'е п',
#  'а Г',
#  'е н',
#  'а п',
#  'о в',
#  'е н',
#  'а п',
#  'о б',
#  'о к',
#  'о т',
#  'и П']

# %%
f = open('StudentsPerformance.csv')

# %%
for line in f:
    print(line)
f.close()
# Out:
# "gender","race/ethnicity","parental level of education","lunch","test preparation course","math score","reading score","writing score"
#
# "female","group B","bachelor's degree","standard","none","72","72","74"
#
# "female","group C","some college","standard","completed","69","90","88"
#
# "female","group B","master's degree","standard","none","90","95","93"
#
# "male","group A","associate's degree","free/reduced","none","47","57","44"
#
# "male","group C","some college","standard","none","76","78","75"
#
# "female","group B","associate's degree","standard","none","71","83","78"
#
# "female","group B","some college","standard","completed","88","95","92"
#
# "male","group B","some college","free/reduced","none","40","43","39"
#
# "male","group D","high school","free/reduced","completed","64","64","67"
#
# "female","group B","high school","free/reduced","none","38","60","50"
#
# "male","group C","associate's degree","standard","none","58","54","52"
#
# ...

# %%
f = open('StudentsPerformance.csv')
males = 0
females = 0
for line in f:
    info = line.split(',')
    gender = info[0][1: -1]
    if gender == 'female':
        females += 1
    elif gender == 'male':
        males += 1
print('Мальчиков: {}, девочек: {}'.format(males, females))
# Out:
# Мальчиков: 482, девочек: 518

# %%
f = open('StudentsPerformance.csv')
bachelor = 0
for line in f:
    info = line.split(',')
    degree = info[2][1: -1]
    if degree == 'bachelor\'s degree':
        bachelor += 1
print(bachelor)
# Out:
# 118

# %%
f = open('StudentsPerformance.csv')
levels = []
for line in f:
    info = line.split(',')
    level = info[2][1: -1]
    if level not in levels and level != 'parental level of education':
        levels.append(level)
print(len(levels))
# Out:
# 6

# %%
f = open('StudentsPerformance.csv')
lunches = 0
students = 0
for line in f:
    info = line.split(',')
    lunch = info[3][1: -1]
    students += 1
    if lunch == 'standard':
        lunches += 1
print(lunches/(students - 1) * 100)
# Out:
# 64.5

# %%
f = open('StudentsPerformance.csv')
f.readline()
groupC = 0
for line in f:
    info = line.split(',')
    group = info[1][1: -1]
    if group == 'group C':
        groupC += 1
print(groupC)
# Out:
# 319

# %%
f = open('StudentsPerformance.csv')
f.readline()
ethnicities = list()
for line in f:
    info = line.split(',')
    ethnicity = info[1][1: -1]
    if ethnicity not in ethnicities:
        ethnicities.append(ethnicity)
print(len(ethnicities))
# Out:
# 5

# %%
math = []
f = open('StudentsPerformance.csv')
for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        mark = int(info[5][1: -1])
        math.append(mark)
math_avg = sum(math)/len(math)
print(math_avg)
above_avg = 0
for mark in math:
    if mark > math_avg:
        above_avg += 1
print(above_avg / (students - 1))
# Out:
# 66.089
# 0.493

# %%
import re
pattern = re.compile('\d+')

exams = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        new_line = []
        for item in info:
            matchobj = pattern.search(item)
            if matchobj != None:
                new_line.append(int(matchobj[1]))
                print(matchobj)
            else:
                new_line.append(item[1: -1])
        exams.append(new_line)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-140-9c8906e493ae> in <module>
#      15             matchobj = pattern.search(item)
#      16             if matchobj != None:
# ---> 17                 new_line.append(int(matchobj[1]))
#      18                 print(matchobj)
#      19             else:
#
# IndexError: no such group

# %%
reading = []
f = open('StudentsPerformance.csv')
for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        r_mark = int(info[6][1: -1])
        reading.append(r_mark)
read_avg = sum(reading)/len(reading)
print(read_avg)
below_avg = 0
for r_mark in reading:
    if r_mark < read_avg:
        below_avg += 1
print(below_avg)
# Out:
# 69.169
# 487

# %%
reading_girls = []
f = open('StudentsPerformance.csv')
for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        if info[0] == '"female"':
            r_mark_g = int(info[6][1: -1])
            reading_girls.append(r_mark_g)
read_avg = sum(reading_girls)/len(reading_girls)
print(read_avg)
below_avg = 0
for r_mark in reading:
    if r_mark < read_avg:
        below_avg += 1
print(below_avg)
# Out:
# 72.60810810810811
# 567

# %%
students = 0
had_lunch = 0
f = open('StudentsPerformance.csv')
for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        w_mark = int(info[7][1: -2])
        lunch = info[3][1:-1]
        if w_mark > 90:
            students += 1
            if lunch == 'standard':
               had_lunch += 1
result = had_lunch/students * 100
print(result)
# Out:
# 86.76470588235294

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1: -1]
        if ethnicity in students:
            students[ethnicity] += 1
        else:
            students[ethnicity] = 1
students
# Out:
# {'group B': 190, 'group C': 319, 'group A': 89, 'group D': 262, 'group E': 140}

# %%
students['group A']
# Out:
# 89

# %%
for group, number in students.items():
    print(group, number)
# Out:
# group B 190
# group C 319
# group A 89
# group D 262
# group E 140

# %%
total = 0
for number in students.values():
    total += int(number)
print(total)
# Out:
# 1000

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1: -1]
        parents = info[2][1: -1]
        if ethnicity in students:
            if parents in students[ethnicity]:
                students[ethnicity][parents] += 1
            else:
                students[ethnicity][parents] = 1
        else:
            students[ethnicity] = {}
            students[ethnicity][parents] = 1
students
# Out:
# {'group B': {"bachelor's degree": 20,
#   "master's degree": 6,
#   "associate's degree": 41,
#   'some college': 37,
#   'high school': 48,
#   'some high school': 38},
#  'group C': {'some college': 69,
#   "associate's degree": 78,
#   'some high school': 49,
#   'high school': 64,
#   "master's degree": 19,
#   "bachelor's degree": 40},
#  'group A': {"associate's degree": 14,
#   'some college': 18,
#   "master's degree": 3,
#   'some high school': 24,
#   "bachelor's degree": 12,
#   'high school': 18},
#  'group D': {'high school': 44,
#   "associate's degree": 50,
#   'some college': 67,
#   "bachelor's degree": 28,
#   "master's degree": 23,
#   'some high school': 50},
#  'group E': {"master's degree": 8,
#   'some college': 35,
#   "associate's degree": 39,
#   "bachelor's degree": 18,
#   'some high school': 18,
#   'high school': 22}}

# %%
lunch_boys = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        gender = info[0][1: -1]
        lunch = info[3][1: -1]
        if gender in lunch_boys:
            if lunch in lunch_boys[gender]:
                lunch_boys[gender][lunch] += 1
            else:
                lunch_boys[gender][lunch] = 1
        else:
            lunch_boys[gender] = {}
            lunch_boys[gender][lunch] = 1
print(lunch_boys)
# Out:
# {'female': {'standard': 329, 'free/reduced': 189}, 'male': {'free/reduced': 166, 'standard': 316}}

# %%
students = {}
counter = 0
f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        gender = info[0][1:-1]
        lunch = info[3][1:-1]
        if gender == 'male' and lunch == 'standard': 
            counter += 1          
print(counter)
# Out:
# 316

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        gender = info[0][1:-1]
        lunch = info[3][1:-1]
        if gender in students:
            if lunch in students[gender]:
                students[gender][lunch] += 1
            else:
                students[gender][lunch] = 1
        else:
            students[gender] = {}
            students[gender][lunch] = 1
            
print(students['male']['standard'])
# Out:
# 316

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        gender = info[0][1: -1]
        prep = info[4][1: -1]
        if gender in students:
            if prep in students[gender]:
                students[gender][prep] += 1
            else:
                students[gender][prep] = 1
        else:
            students[gender] =  {}
            students[gender][prep] = 1
print(students['male']['completed'])
# Out:
# 174

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        gender = info[0][1: -1]
        parents_edu = info[2][1: -1]
        if gender in students:
            if parents_edu in students[gender]:
                students[gender][parents_edu] += 1
            else:
                students[gender][parents_edu] = 1
        else:
            students[gender] = {}
            students[gender][parents_edu] = 1
students
#print(students['female']['master\'s degree'])
# Out:
# {'female': {"bachelor's degree": 63,
#   'some college': 118,
#   "master's degree": 36,
#   "associate's degree": 116,
#   'high school': 94,
#   'some high school': 91},
#  'male': {"associate's degree": 106,
#   'some college': 108,
#   'high school': 102,
#   "master's degree": 23,
#   "bachelor's degree": 55,
#   'some high school': 88}}

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1: -1]
        prep = info[4][1: -1]
        if ethnicity in students:
            if prep in students[ethnicity]:
                students[ethnicity][prep] += 1
            else:
                students[ethnicity][prep] = 1
        else:
            students[ethnicity] = {}
            students[ethnicity][prep] = 1
students
print(students['group C']['completed'])
# Out:
# 117

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        gender = info[0][1: -1]
        parents_edu = info[2][1: -1]
        score = int(info[5][1: -1])
        if gender in students:
            if score > 90:
                if parents_edu in students[gender]:
                    students[gender][parents_edu] += 1
                else:
                    students[gender][parents_edu] = 1
        else:
            students[gender] = {}
            students[gender][parents_edu] = 1
print(students['female']['master\'s degree'])
# Out:
# 2

# %%
read = []
f = open('StudentsPerformance.csv')
for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        gender = info[0][1: -1]
        mark = int(info[6][1: -1])
        if gender == 'male':
            read.append(mark)
read_avg = sum(read)/len(read)
print(read_avg)
# Out:
# 65.47302904564316

# %%
read_score = list()
math_score = list()
temp = []
f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    #else:
    math = int(info[5][1:-1])
    read = int(info[6][1: -1])
    math_score.append(math)
    temp.append({'math': math,'read': read})
        
math_max = max(math_score)
print(temp)

for line in temp:
    #print(line['read'])
    if line['math'] == max(math_score):
        read_score.append(line['read'])      
avg_read = sum(read_score) / len(read_score)
print(avg_read)
# Out:
# [{'math': 72, 'read': 72}, {'math': 69, 'read': 90}, {'math': 90, 'read': 95}, {'math': 47, 'read': 57}, {'math': 76, 'read': 78}, {'math': 71, 'read': 83}, {'math': 88, 'read': 95}, {'math': 40, 'read': 43}, {'math': 64, 'read': 64}, {'math': 38, 'read': 60}, {'math': 58, 'read': 54}, {'math': 40, 'read': 52}, {'math': 65, 'read': 81}, {'math': 78, 'read': 72}, {'math': 50, 'read': 53}, {'math': 69, 'read': 75}, {'math': 88, 'read': 89}, {'math': 18, 'read': 32}, {'math': 46, 'read': 42}, {'math': 54, 'read': 58}, {'math': 66, 'read': 69}, {'math': 65, 'read': 75}, {'math': 44, 'read': 54}, {'math': 69, 'read': 73}, {'math': 74, 'read': 71}, {'math': 73, 'read': 74}, {'math': 69, 'read': 54}, {'math': 67, 'read': 69}, {'math': 70, 'read': 70}, {'math': 62, 'read': 70}, {'math': 69, 'read': 74}, {'math': 63, 'read': 65}, {'math': 56, 'read': 72}, {'math': 40, 'read': 42}, {'math': 97, 'read': 87}, {'math': 81, 'read': 81}, {'math': 74, 'read': 81}, {'math': 50, 'read': 64}, {'math': 
# ...

# %%
writing_score = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        writing = int(info[-1][1:-2])
        lunch = info[3][1: -1]
        if lunch == 'free/reduced':
            writing_score.append(writing)
wr_avg = sum(writing_score) / len(writing_score)
print(wr_avg)
# Out:
# 63.02253521126761
